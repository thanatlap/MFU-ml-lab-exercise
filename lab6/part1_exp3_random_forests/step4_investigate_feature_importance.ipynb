# %%
import numpy
import pandas
import joblib

import seaborn
# %matplotlib inline

# %% [markdown]
# # Instructions¶
# - Use `joblib` to load the trained model
# - Create a `pandas.DataFrame` having columns `feature_name` and `feature_importance`
#     - Hint: using `feature_names_in_` and `feature_importances_`
#     - Also, sort the `feature_importance` in descending order

# %%
model = joblib.load('model/model.joblib')
model
# Out:
# RandomForestClassifier(criterion='entropy', random_state=0)

# %%
feature_importance = pandas.DataFrame({
    'feature_name': model.feature_names_in_,
    'feature_importance': model.feature_importances_,
})

feature_importance.sort_values(
    by = 'feature_importance', 
    ascending = False,
    inplace = True
)
feature_importance
# Out:
#                                      feature_name  feature_importance
# 1                                   credit_amount            0.099614
# 2                                             age            0.082216
# 0                                        duration            0.080859
# 14                    checking_status_no checking            0.045010
# 3                                      employment            0.041447
# 15                             checking_status_<0            0.038644
# 6                          installment_commitment            0.035926
# 7                                 residence_since            0.035002
# 8                                existing_credits            0.021016
# 20  credit_history_critical/other existing credit            0.020209
# 48                 property_magnitude_real estate            0.018227
# 4                                   own_telephone            0.017686
# ...

# %% [markdown]
# # Instruction
# - Use the following code snippet to plot feature importance:
# ```
# seaborn.set(
#     style = 'whitegrid',
#     rc    = {'figure.figsize': (8, 15)}
# )
#
# seaborn.barplot(
#     data=feature_importance,
#     x='feature_importance',
#     y='feature_name'
# )
# ```

# %%
seaborn.set(
    style = 'whitegrid', 
    rc    = {'figure.figsize': (8, 15)}
)

seaborn.barplot(
    data=feature_importance,
    x='feature_importance', 
    y='feature_name'
)
# Out:
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='feature_importance', ylabel='feature_name'>
