# %%
import pandas
import joblib

# %% [markdown]
# # Instructions
#
# - Read **the live data** from the CSV file and properly set the index
# - Load the trained model

# %%
# Out:
#      duration  credit_amount       age  employment  own_telephone  \
# id
# 271 -0.724523      -0.656302  0.117817         3.0            1.0
# 726 -0.474922      -0.687389  0.986924         2.0            0.0
# 31   0.273882       0.290057 -0.751289         2.0            0.0
# 343 -0.225321       0.441518 -0.229825         4.0            1.0
# 605  0.273882      -0.140829 -1.185843         2.0            1.0
# ..        ...            ...       ...         ...            ...
# 725 -1.223726      -1.072729  0.465460         2.0            0.0
# 747 -0.724523      -0.702571  0.117817         1.0            0.0
# 534  0.273882      -0.040698 -0.925111         1.0            0.0
# 97  -0.225321      -0.215294 -0.142915         2.0            0.0
# 268 -0.558122       2.082283  0.813103         4.0            1.0
#
#      foreign_worker  installment_commitment  residence_since  \
# id
# 271             1.0                     2.0              3.0
# ...

# %%
# Out:
# MLPClassifier(activation='logistic', alpha=0.0, batch_size=32,
#               hidden_layer_sizes=(20, 10), learning_rate_init=0.1,
#               max_iter=1000, momentum=0.0, n_iter_no_change=1000,
#               nesterovs_momentum=False, random_state=0, solver='sgd',
#               validation_fraction=0.0)

# %% [markdown]
# # Instructions
# - Calculate predictions for the live data and properly formatted as a dataframe
# - Write the dataframe to `./results/predictions.live.csv`
# - **Verify that the output file contains valid predictions that are properly indexed**

# %%
# Out:
#      prediction
# id
# 271         0.0
# 726         0.0
# 31          1.0
# 343         0.0
# 605         0.0
# ..          ...
# 725         0.0
# 747         0.0
# 534         0.0
# 97          0.0
# 268         1.0
#
# [100 rows x 1 columns]
