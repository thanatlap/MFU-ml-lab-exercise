# %%
import numpy
import pandas
import joblib
import json
import seaborn

import sklearn

# %matplotlib inline

# %% [markdown]
# # Instructions
#
# - Read **the test data** from the CSV file and properly set the index
# - Load the trained model

# %%
# Out:
#      duration  credit_amount       age  employment  own_telephone  \
# id
# 271 -0.724523      -0.656302  0.117817         3.0            1.0
# 726 -0.474922      -0.687389  0.986924         2.0            0.0
# 31   0.273882       0.290057 -0.751289         2.0            0.0
# 343 -0.225321       0.441518 -0.229825         4.0            1.0
# 605  0.273882      -0.140829 -1.185843         2.0            1.0
# ..        ...            ...       ...         ...            ...
# 75  -0.724523      -0.611478  2.638227         4.0            0.0
# 454  0.273882       0.578158 -0.403647         3.0            1.0
# 468  1.022686      -0.163964 -0.838200         2.0            1.0
# 386 -0.225321      -0.756071 -1.272753         1.0            1.0
# 492 -1.223726      -0.715946 -0.751289         2.0            0.0
#
#      foreign_worker  installment_commitment  residence_since  \
# id
# 271             1.0                     2.0              3.0
# 726             1.0                     1.0              1.0
# 31              1.0                     1.0              1.0
# 343             1.0                     0.0              0.0
# 605             1.0                     3.0              3.0
# ..              ...                     ...              ...
# 75              1.0                     3.0              3.0
# 454             1.0                     1.0              2.0
# 468             1.0                     1.0              1.0
# 386             1.0                     3.0              1.0
# 492             1.0                     0.0              0.0
#
#      existing_credits  num_dependents  ...  property_magnitude_life insurance  \
# id                                     ...
# 271               0.0             0.0  ...                                0.0
# 726               1.0             0.0  ...                                1.0
# 31                0.0             0.0  ...                                0.0
# 343               0.0             0.0  ...                                0.0
# 605               0.0             0.0  ...                                0.0
# ..                ...             ...  ...                                ...
# 75                1.0             0.0  ...                                0.0
# 454               0.0             0.0  ...                                1.0
# 468               1.0             0.0  ...                                0.0
# 386               0.0             0.0  ...                                0.0
# 492               1.0             0.0  ...                                1.0
#
#      property_magnitude_car  property_magnitude_real estate  \
# id
# 271                     1.0                             0.0
# 726                     0.0                             0.0
# 31                      1.0                             0.0
# 343                     0.0                             1.0
# 605                     0.0                             1.0
# ..                      ...                             ...
# 75                      0.0                             0.0
# 454                     0.0                             0.0
# 468                     1.0                             0.0
# 386                     0.0                             1.0
# 492                     0.0                             0.0
#
#      other_payment_plans_none  other_payment_plans_stores  \
# id
# 271                       1.0                         0.0
# 726                       1.0                         0.0
# 31                        0.0                         1.0
# 343                       0.0                         0.0
# 605                       0.0                         1.0
# ..                        ...                         ...
# 75                        1.0                         0.0
# 454                       1.0                         0.0
# 468                       1.0                         0.0
# 386                       1.0                         0.0
# 492                       1.0                         0.0
#
#      other_payment_plans_bank  housing_for free  housing_rent  housing_own  \
# id
# 271                       0.0               0.0           1.0          0.0
# 726                       0.0               0.0           0.0          1.0
# 31                        0.0               0.0           0.0          1.0
# 343                       1.0               0.0           0.0          1.0
# 605                       0.0               0.0           0.0          1.0
# ..                        ...               ...           ...          ...
# 75                        0.0               1.0           0.0          0.0
# 454                       0.0               0.0           0.0          1.0
# 468                       0.0               0.0           0.0          1.0
# 386                       0.0               0.0           1.0          0.0
# 492                       0.0               0.0           0.0          1.0
#
#      label
# id
# 271    0.0
# 726    0.0
# 31     0.0
# 343    0.0
# 605    0.0
# ..     ...
# 75     0.0
# 454    1.0
# 468    0.0
# 386    0.0
# 492    0.0
#
# [250 rows x 56 columns]

# %%
# Out:
# MLPClassifier(activation='logistic', alpha=0.008, batch_size=32,
#               hidden_layer_sizes=(20, 10), learning_rate_init=0.1,
#               max_iter=1000, momentum=0.0, nesterovs_momentum=False,
#               random_state=0, solver='sgd', validation_fraction=0.0)

# %% [markdown]
# # Instructions
# - Calculate and add the `prediction` column to the dataframe of test data
# - Write the dataframe to `./results/predictions.test.csv`

# %%
# Out:
#      duration  credit_amount       age  employment  own_telephone  \
# id
# 271 -0.724523      -0.656302  0.117817         3.0            1.0
# 726 -0.474922      -0.687389  0.986924         2.0            0.0
# 31   0.273882       0.290057 -0.751289         2.0            0.0
# 343 -0.225321       0.441518 -0.229825         4.0            1.0
# 605  0.273882      -0.140829 -1.185843         2.0            1.0
# ..        ...            ...       ...         ...            ...
# 75  -0.724523      -0.611478  2.638227         4.0            0.0
# 454  0.273882       0.578158 -0.403647         3.0            1.0
# 468  1.022686      -0.163964 -0.838200         2.0            1.0
# 386 -0.225321      -0.756071 -1.272753         1.0            1.0
# 492 -1.223726      -0.715946 -0.751289         2.0            0.0
#
#      foreign_worker  installment_commitment  residence_since  \
# id
# 271             1.0                     2.0              3.0
# 726             1.0                     1.0              1.0
# 31              1.0                     1.0              1.0
# 343             1.0                     0.0              0.0
# 605             1.0                     3.0              3.0
# ..              ...                     ...              ...
# 75              1.0                     3.0              3.0
# 454             1.0                     1.0              2.0
# 468             1.0                     1.0              1.0
# 386             1.0                     3.0              1.0
# 492             1.0                     0.0              0.0
#
#      existing_credits  num_dependents  ...  property_magnitude_car  \
# id                                     ...
# 271               0.0             0.0  ...                     1.0
# 726               1.0             0.0  ...                     0.0
# 31                0.0             0.0  ...                     1.0
# 343               0.0             0.0  ...                     0.0
# 605               0.0             0.0  ...                     0.0
# ..                ...             ...  ...                     ...
# 75                1.0             0.0  ...                     0.0
# 454               0.0             0.0  ...                     0.0
# 468               1.0             0.0  ...                     1.0
# 386               0.0             0.0  ...                     0.0
# 492               1.0             0.0  ...                     0.0
#
#      property_magnitude_real estate  other_payment_plans_none  \
# id
# 271                             0.0                       1.0
# 726                             0.0                       1.0
# 31                              0.0                       0.0
# 343                             1.0                       0.0
# 605                             1.0                       0.0
# ..                              ...                       ...
# 75                              0.0                       1.0
# 454                             0.0                       1.0
# 468                             0.0                       1.0
# 386                             1.0                       1.0
# 492                             0.0                       1.0
#
#      other_payment_plans_stores  other_payment_plans_bank  housing_for free  \
# id
# 271                         0.0                       0.0               0.0
# 726                         0.0                       0.0               0.0
# 31                          1.0                       0.0               0.0
# 343                         0.0                       1.0               0.0
# 605                         1.0                       0.0               0.0
# ..                          ...                       ...               ...
# 75                          0.0                       0.0               1.0
# 454                         0.0                       0.0               0.0
# 468                         0.0                       0.0               0.0
# 386                         0.0                       0.0               0.0
# 492                         0.0                       0.0               0.0
#
#      housing_rent  housing_own  label  prediction
# id
# 271           1.0          0.0    0.0         0.0
# 726           0.0          1.0    0.0         0.0
# 31            0.0          1.0    0.0         1.0
# 343           0.0          1.0    0.0         0.0
# 605           0.0          1.0    0.0         1.0
# ..            ...          ...    ...         ...
# 75            0.0          0.0    0.0         0.0
# 454           0.0          1.0    1.0         1.0
# 468           0.0          1.0    0.0         0.0
# 386           1.0          0.0    0.0         0.0
# 492           0.0          1.0    0.0         0.0
#
# [250 rows x 57 columns]

# %% [markdown]
# # Instructions
# - Use `sklearn.metrics.confusion_matrix` to calculate the confusion matrix

# %%
# Out:
# array([[151,  34],
#        [ 23,  42]])

# %% [markdown]
# # Instructions
#
# - Use `sklearn.metrics.classification_report` to print the classification report
# - Now, **manually fill** the following metrics `y=1` and put them in a Python dictionary
# - The expected output should look like:
#
# ```
# scores = {
#      'true_positive': 42,
#      'true_negative': 151,
#      'false_negative': 34,
#      'false_positive': 23,
#      'accuracy': 0.772,
#      'precision': 0.552,
#      'recall': 0.646,
#      'support': 65,
#      'f1-score': 0.595
# }
# ```
# - Use `json.dump` to save the output to  `./results/scores.test.json`

# %%
# Out:
#                   0.0        1.0  accuracy   macro avg  weighted avg
# precision    0.867816   0.552632     0.772    0.710224      0.785868
# recall       0.816216   0.646154     0.772    0.731185      0.772000
# f1-score     0.841226   0.595745     0.772    0.718485      0.777401
# support    185.000000  65.000000     0.772  250.000000    250.000000
