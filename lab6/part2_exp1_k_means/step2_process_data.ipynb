# %%
import pandas
import seaborn

# %matplotlib inline

# %% [markdown]
# # Instructions
#
# - Read the data from CSV files and properly set the indices
# - For the sake of simplicity, data processing is omitted for this experiment
# - Use `seaborn.scatterplot` to visualize features on both data sets
# - Simply write the train data set to `./data/features.train.csv`
# - Simply write the test data set to `./data/features.test.csv`

# %%
data_train = pandas.read_csv('../data/blobs.train.csv').set_index('id')
data_train
# Out:
#      feature_1  feature_2
# id
# 253     2.1592     0.0103
# 667    -5.1157     0.8180
# 85      1.8528    -0.0038
# 969    -6.3364    -1.9423
# 75     -5.8828    -2.6060
# ..         ...        ...
# 835     2.1841     0.0434
# 192    -8.5461    -8.3446
# 629    -7.6355    -6.3077
# 559     2.0941     1.1079
# 684    -8.9178    -4.2373
#
# [750 rows x 2 columns]

# %%
data_test = pandas.read_csv('../data/blobs.test.csv').set_index('id')
data_test
# Out:
#      feature_1  feature_2
# id
# 993     1.5434     0.9746
# 859    -5.4491    -1.5294
# 298    -7.1086    -1.0547
# 553     1.4975     0.6471
# 672    -8.4150    -6.3597
# ..         ...        ...
# 462    -5.7266    -1.9039
# 356    -7.7180    -1.4188
# 2       2.2098     0.3167
# 478   -10.2702    -5.1999
# 695     2.5395     0.7373
#
# [250 rows x 2 columns]

# %%
seaborn.scatterplot(
    data_train,
    x   = 'feature_1',
    y   = 'feature_2',
)
# Out:
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='feature_1', ylabel='feature_2'>

# %%
seaborn.scatterplot(
    data_test,
    x   = 'feature_1',
    y   = 'feature_2',
)
# Out:
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='feature_1', ylabel='feature_2'>

# %%
data_train.to_csv('./data/features.train.csv')

# %%
data_test.to_csv('./data/features.test.csv')
