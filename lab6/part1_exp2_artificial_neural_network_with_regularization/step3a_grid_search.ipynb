# %%
import joblib
import json
import pandas
import warnings
import numpy

import sklearn.neural_network
import sklearn.model_selection
import sklearn.exceptions

warnings.filterwarnings("ignore", category=sklearn.exceptions.ConvergenceWarning)

# %% [markdown]
# # Instructions
#
# - Read **the train data** from the CSV file and properly set the index

# %%
data_train = pandas.read_csv('./data/features.train.csv').set_index('id')
data_train
# Out:
#      duration  credit_amount       age  employment  own_telephone  \
# id
# 253  0.277814       0.320904 -0.080669         2.0            0.0
# 667  2.289342       0.130313 -0.765274         2.0            0.0
# 85  -0.727949      -0.642249 -0.594123         2.0            1.0
# 969 -0.811763       0.246356  0.347209         2.0            0.0
# 75  -0.727949      -0.602162  2.572174         4.0            0.0
# ..        ...            ...       ...         ...            ...
# 835 -0.727949      -0.758292  1.031813         2.0            0.0
# 192  0.529255       0.237916  0.004906         2.0            1.0
# 629 -0.979390       0.208730  2.401022         4.0            0.0
# 559 -0.225068      -0.460801 -0.422972         1.0            0.0
# 684  1.283578       2.327386 -0.422972         3.0            1.0
#
#      foreign_worker  installment_commitment  residence_since  \
# id
# 253             1.0                     1.0              2.0
# 667             1.0                     0.0              0.0
# 85              1.0                     3.0              1.0
# 969             1.0                     0.0              1.0
# 75              1.0                     3.0              3.0
# ..              ...                     ...              ...
# 835             1.0                     3.0              3.0
# 192             1.0                     3.0              1.0
# 629             1.0                     0.0              3.0
# 559             1.0                     1.0              1.0
# 684             1.0                     0.0              2.0
#
#      existing_credits  num_dependents  ...  property_magnitude_life insurance  \
# id                                     ...
# 253               1.0             0.0  ...                                1.0
# 667               0.0             0.0  ...                                0.0
# 85                1.0             0.0  ...                                0.0
# 969               1.0             1.0  ...                                0.0
# 75                1.0             0.0  ...                                0.0
# ..                ...             ...  ...                                ...
# 835               1.0             0.0  ...                                0.0
# 192               0.0             1.0  ...                                0.0
# 629               0.0             0.0  ...                                0.0
# 559               1.0             0.0  ...                                0.0
# 684               1.0             1.0  ...                                1.0
#
#      property_magnitude_car  property_magnitude_real estate  \
# id
# 253                     0.0                             0.0
# 667                     0.0                             1.0
# 85                      0.0                             1.0
# 969                     0.0                             1.0
# 75                      0.0                             0.0
# ..                      ...                             ...
# 835                     1.0                             0.0
# 192                     1.0                             0.0
# 629                     0.0                             1.0
# 559                     0.0                             1.0
# 684                     0.0                             0.0
#
#      other_payment_plans_none  other_payment_plans_stores  \
# id
# 253                       1.0                         0.0
# 667                       0.0                         1.0
# 85                        1.0                         0.0
# 969                       1.0                         0.0
# 75                        1.0                         0.0
# ..                        ...                         ...
# 835                       0.0                         0.0
# 192                       1.0                         0.0
# 629                       1.0                         0.0
# 559                       1.0                         0.0
# 684                       1.0                         0.0
#
#      other_payment_plans_bank  housing_for free  housing_rent  housing_own  \
# id
# 253                       0.0               0.0           0.0          1.0
# 667                       0.0               0.0           0.0          1.0
# 85                        0.0               0.0           0.0          1.0
# 969                       0.0               0.0           0.0          1.0
# 75                        0.0               1.0           0.0          0.0
# ..                        ...               ...           ...          ...
# 835                       1.0               0.0           0.0          1.0
# 192                       0.0               0.0           0.0          1.0
# 629                       0.0               0.0           0.0          1.0
# 559                       0.0               0.0           0.0          1.0
# 684                       0.0               0.0           0.0          1.0
#
#      label
# id
# 253    0.0
# 667    0.0
# 85     0.0
# 969    0.0
# 75     0.0
# ..     ...
# 835    1.0
# 192    1.0
# 629    0.0
# 559    1.0
# 684    0.0
#
# [750 rows x 56 columns]

# %%
search_parameters = {
    # 'alpha': [0.2, 0.1, 0.05, 0.01, 0.005, 0.001, 0.0005, 0.0001, 0.00005, 0.00001]
    'alpha': numpy.arange(0.001, 0.011, 0.001)
}

# %%
model = sklearn.neural_network.MLPClassifier(
    hidden_layer_sizes=(20, 10),
    solver='sgd', 
    activation='logistic',
    alpha=0.0,  
    batch_size=32,
    learning_rate='constant',
    learning_rate_init=0.1,
    max_iter=2000,
    momentum=0.0, 
    nesterovs_momentum=False, 
    shuffle=True,
    random_state=0
)

# %%
model = sklearn.model_selection.GridSearchCV(
    estimator=model, 
    param_grid=search_parameters,
    n_jobs=-1,
    verbose=2
)

# %%
model.fit(
    data_train.drop(['label'], axis='columns'),
    data_train['label'],
)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# GridSearchCV(estimator=MLPClassifier(activation='logistic', alpha=0.0,
#                                      batch_size=32, hidden_layer_sizes=(20, 10),
#                                      learning_rate_init=0.1, max_iter=2000,
#                                      momentum=0.0, nesterovs_momentum=False,
#                                      random_state=0, solver='sgd'),
#              n_jobs=-1,
#              param_grid={'alpha': array([0.001, 0.002, 0.003, 0.004, 0.005, 0.006, 0.007, 0.008, 0.009,
#        0.01 ])},
#              verbose=2)

# %%
cv_results = pandas.DataFrame(model.cv_results_)
cv_results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_alpha  \
# 0       2.901165      2.317940         0.003097        0.000470       0.001
# 1       3.004087      2.466210         0.003764        0.001672       0.002
# 2       2.593358      2.271103         0.002048        0.000192       0.003
# 3       2.095070      1.364303         0.002501        0.000722       0.004
# 4       2.003820      1.082840         0.002525        0.000501       0.005
# 5       1.554941      0.868395         0.002347        0.000515       0.006
# 6       1.783271      0.913148         0.002757        0.001086       0.007
# 7       1.376240      0.205042         0.002149        0.000316       0.008
# 8       1.382648      0.139024         0.002464        0.000637       0.009
# 9       1.421652      0.164297         0.002633        0.000780        0.01
#
#                             params  split0_test_score  split1_test_score  \
# 0                 {'alpha': 0.001}               0.78           0.733333
# 1                 {'alpha': 0.002}               0.78           0.740000
# 2                 {'alpha': 0.003}               0.78           0.740000
# 3                 {'alpha': 0.004}               0.78           0.740000
# 4                 {'alpha': 0.005}               0.78           0.740000
# 5                 {'alpha': 0.006}               0.78           0.740000
# 6                 {'alpha': 0.007}               0.78           0.740000
# 7                 {'alpha': 0.008}               0.78           0.740000
# 8  {'alpha': 0.009000000000000001}               0.78           0.740000
# 9  {'alpha': 0.010000000000000002}               0.78           0.740000
#
#    split2_test_score  split3_test_score  split4_test_score  mean_test_score  \
# 0           0.773333           0.713333           0.786667         0.757333
# 1           0.773333           0.713333           0.786667         0.758667
# 2           0.773333           0.713333           0.786667         0.758667
# 3           0.773333           0.760000           0.786667         0.768000
# 4           0.773333           0.766667           0.786667         0.769333
# 5           0.773333           0.773333           0.786667         0.770667
# 6           0.773333           0.773333           0.793333         0.772000
# 7           0.773333           0.706667           0.793333         0.758667
# 8           0.773333           0.706667           0.793333         0.758667
# 9           0.773333           0.706667           0.793333         0.758667
#
#    std_test_score  rank_test_score
# 0        0.028783               10
# 1        0.027777                5
# 2        0.027777                5
# 3        0.016546                4
# 4        0.016111                3
# 5        0.016111                2
# 6        0.017588                1
# 7        0.031383                5
# 8        0.031383                5
# 9        0.031383                5

# %%
cv_results.sort_values(['rank_test_score'])
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_alpha  \
# 6       1.783271      0.913148         0.002757        0.001086       0.007
# 5       1.554941      0.868395         0.002347        0.000515       0.006
# 4       2.003820      1.082840         0.002525        0.000501       0.005
# 3       2.095070      1.364303         0.002501        0.000722       0.004
# 1       3.004087      2.466210         0.003764        0.001672       0.002
# 2       2.593358      2.271103         0.002048        0.000192       0.003
# 7       1.376240      0.205042         0.002149        0.000316       0.008
# 8       1.382648      0.139024         0.002464        0.000637       0.009
# 9       1.421652      0.164297         0.002633        0.000780        0.01
# 0       2.901165      2.317940         0.003097        0.000470       0.001
#
#                             params  split0_test_score  split1_test_score  \
# 6                 {'alpha': 0.007}               0.78           0.740000
# 5                 {'alpha': 0.006}               0.78           0.740000
# 4                 {'alpha': 0.005}               0.78           0.740000
# 3                 {'alpha': 0.004}               0.78           0.740000
# 1                 {'alpha': 0.002}               0.78           0.740000
# 2                 {'alpha': 0.003}               0.78           0.740000
# 7                 {'alpha': 0.008}               0.78           0.740000
# 8  {'alpha': 0.009000000000000001}               0.78           0.740000
# 9  {'alpha': 0.010000000000000002}               0.78           0.740000
# 0                 {'alpha': 0.001}               0.78           0.733333
#
#    split2_test_score  split3_test_score  split4_test_score  mean_test_score  \
# 6           0.773333           0.773333           0.793333         0.772000
# 5           0.773333           0.773333           0.786667         0.770667
# 4           0.773333           0.766667           0.786667         0.769333
# 3           0.773333           0.760000           0.786667         0.768000
# 1           0.773333           0.713333           0.786667         0.758667
# 2           0.773333           0.713333           0.786667         0.758667
# 7           0.773333           0.706667           0.793333         0.758667
# 8           0.773333           0.706667           0.793333         0.758667
# 9           0.773333           0.706667           0.793333         0.758667
# 0           0.773333           0.713333           0.786667         0.757333
#
#    std_test_score  rank_test_score
# 6        0.017588                1
# 5        0.016111                2
# 4        0.016111                3
# 3        0.016546                4
# 1        0.027777                5
# 2        0.027777                5
# 7        0.031383                5
# 8        0.031383                5
# 9        0.031383                5
# 0        0.028783               10

# %%
model.best_params_
# Out:
# {'alpha': 0.007}
