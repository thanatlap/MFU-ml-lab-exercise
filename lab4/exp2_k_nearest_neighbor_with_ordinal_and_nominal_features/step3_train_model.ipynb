# %%
import joblib
import json
import pandas

import sklearn.neighbors

# %% [markdown]
# # Instructions
#
# - Read **the train data** from the CSV file and properly set the index

# %%
# Out:
#      duration  credit_amount  age  employment  own_telephone  foreign_worker  \
# id
# 253      24.0         4151.0   35         2.0            0.0             1.0
# 667      48.0         3609.0   27         2.0            0.0             1.0
# 85       12.0         1412.0   29         2.0            1.0             1.0
# 969      11.0         3939.0   40         2.0            0.0             1.0
# 75       12.0         1526.0   66         4.0            0.0             1.0
# ..        ...            ...  ...         ...            ...             ...
# 835      12.0         1082.0   48         2.0            0.0             1.0
# 192      27.0         3915.0   36         2.0            1.0             1.0
# 629       9.0         3832.0   64         4.0            0.0             1.0
# 559      18.0         1928.0   31         1.0            0.0             1.0
# 684      36.0         9857.0   31         3.0            1.0             1.0
#
#      installment_commitment  residence_since  existing_credits  \
# id
# 253                     1.0              2.0               1.0
# 667                     0.0              0.0               0.0
# 85                      3.0              1.0               1.0
# 969                     0.0              1.0               1.0
# 75                      3.0              3.0               1.0
# ..                      ...              ...               ...
# 835                     3.0              3.0               1.0
# 192                     3.0              1.0               0.0
# 629                     0.0              3.0               0.0
# 559                     1.0              1.0               1.0
# 684                     0.0              2.0               1.0
#
#      num_dependents  ...  property_magnitude_life insurance  \
# id                   ...
# 253             0.0  ...                                1.0
# 667             0.0  ...                                0.0
# 85              0.0  ...                                0.0
# 969             1.0  ...                                0.0
# 75              0.0  ...                                0.0
# ..              ...  ...                                ...
# 835             0.0  ...                                0.0
# 192             1.0  ...                                0.0
# 629             0.0  ...                                0.0
# 559             0.0  ...                                0.0
# 684             1.0  ...                                1.0
#
#      property_magnitude_car  property_magnitude_real estate  \
# id
# 253                     0.0                             0.0
# 667                     0.0                             1.0
# 85                      0.0                             1.0
# 969                     0.0                             1.0
# 75                      0.0                             0.0
# ..                      ...                             ...
# 835                     1.0                             0.0
# 192                     1.0                             0.0
# 629                     0.0                             1.0
# 559                     0.0                             1.0
# 684                     0.0                             0.0
#
#      other_payment_plans_none  other_payment_plans_stores  \
# id
# 253                       1.0                         0.0
# 667                       0.0                         1.0
# 85                        1.0                         0.0
# 969                       1.0                         0.0
# 75                        1.0                         0.0
# ..                        ...                         ...
# 835                       0.0                         0.0
# 192                       1.0                         0.0
# 629                       1.0                         0.0
# 559                       1.0                         0.0
# 684                       1.0                         0.0
#
#      other_payment_plans_bank  housing_for free  housing_rent  housing_own  \
# id
# 253                       0.0               0.0           0.0          1.0
# 667                       0.0               0.0           0.0          1.0
# 85                        0.0               0.0           0.0          1.0
# 969                       0.0               0.0           0.0          1.0
# 75                        0.0               1.0           0.0          0.0
# ..                        ...               ...           ...          ...
# 835                       1.0               0.0           0.0          1.0
# 192                       0.0               0.0           0.0          1.0
# 629                       0.0               0.0           0.0          1.0
# 559                       0.0               0.0           0.0          1.0
# 684                       0.0               0.0           0.0          1.0
#
#      label
# id
# 253    0.0
# 667    0.0
# 85     0.0
# 969    0.0
# 75     0.0
# ..     ...
# 835    1.0
# 192    1.0
# 629    0.0
# 559    1.0
# 684    0.0
#
# [733 rows x 56 columns]

# %% [markdown]
# # Instructions
#
# - Instantiate a `sklearn.neighbors.KNeighborsClassifier` model with the following configurations
# ```
#     n_neighbors=5,
#     weights='uniform',
#     p=2,
# ```
# - Fit the model with data columns properly selected
# - Use `joblib.dump` to save the model to `./model/model.joblib`
# - Also, use `.get_params`, `json.dump` to save the model configuration to  `./model/config.json`

# %%
# Out:
# KNeighborsClassifier()

# %%
# Out:
# ['./model/model.joblib']
