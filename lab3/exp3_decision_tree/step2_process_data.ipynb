# %%
import pandas
import seaborn

# %matplotlib inline

# %% [markdown]
# # Instructions
#
# - Read the data from CSV files and properly set the indices
# - For the sake of simplicity, data processing is omitted for this experiment
# - Use `seaborn.scatterplot` to visualize both features and labels on both data sets
# - Simply write the train data set to `./data/features.train.csv`
# - Simply write the test data set to `./data/features.test.csv`

# %%
data_train = pandas.read_csv('../data/interleaving_moons.train.csv').set_index('id')
data_train
# Out:
#      feature_1  feature_2  label
# id
# 253     2.2189     0.3114      1
# 667    -0.2929     0.3086      1
# 85      0.6741    -0.4251      1
# 969     0.9695    -0.5618      1
# 75     -1.5488     0.6378      0
# ..         ...        ...    ...
# 835     0.6986    -0.2398      1
# 192    -0.4636     0.5754      0
# 629     0.6531     0.2976      0
# 559     1.1244     1.4332      0
# 684     0.3986    -0.8883      1
#
# [750 rows x 3 columns]

# %%
seaborn.scatterplot(
    data_train,
    x   = 'feature_1',
    y   = 'feature_2',
    hue = 'label',
)
# Out:
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='feature_1', ylabel='feature_2'>

# %%
data_train.to_csv('./data/features.train.csv')

# %%
data_test = pandas.read_csv('../data/interleaving_moons.test.csv').set_index('id')
data_test
# Out:
#      feature_1  feature_2  label
# id
# 993     0.6989    -0.8901      1
# 859     0.1954    -0.4052      1
# 298    -1.2008     0.3466      0
# 553    -0.5357     0.9388      0
# 672    -1.3599     0.2303      0
# ..         ...        ...    ...
# 462    -0.5365    -0.4533      0
# 356    -0.4734     0.9849      0
# 2      -0.1904     0.3840      0
# 478     0.7934     0.2027      0
# 695     0.1785     0.6924      1
#
# [250 rows x 3 columns]

# %%
seaborn.scatterplot(
    data_test,
    x   = 'feature_1',
    y   = 'feature_2',
    hue = 'label',
)
# Out:
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='feature_1', ylabel='feature_2'>

# %%
data_test.to_csv('./data/features.test.csv')
