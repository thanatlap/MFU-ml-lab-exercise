# %%
import numpy
import pandas
import joblib
import json
import seaborn
import sklearn

# %matplotlib inline

# %% [markdown]
# # Instructions
#
# - Read **the test data** from the CSV file and properly set the index
# - Load the trained model

# %%
# Out:
#      feature_1  feature_2  label
# id
# 993     0.6989    -0.8901      1
# 859     0.1954    -0.4052      1
# 298    -1.2008     0.3466      0
# 553    -0.5357     0.9388      0
# 672    -1.3599     0.2303      0
# ..         ...        ...    ...
# 462    -0.5365    -0.4533      0
# 356    -0.4734     0.9849      0
# 2      -0.1904     0.3840      0
# 478     0.7934     0.2027      0
# 695     0.1785     0.6924      1
#
# [250 rows x 3 columns]

# %%
# Out:
# LogisticRegression(fit_intercept=False, penalty=None, random_state=0)

# %% [markdown]
# # Instructions
#
# - Calculate and add the `prediction` column to the dataframe of test data
# - Compare the labels with the predictions and put them into 4 `result_type` categories; namely,
#   - true_negative
#   - false_negative
#   - true_positive
#   - false_positive
# - Add the `result_type` column to the dataframe of test data
# - Write the dataframe to `./results/predictions.test.csv`

# %%
# Out:
#      feature_1  feature_2  label  prediction
# id
# 993     0.6989    -0.8901      1           1
# 859     0.1954    -0.4052      1           1
# 298    -1.2008     0.3466      0           0
# 553    -0.5357     0.9388      0           0
# 672    -1.3599     0.2303      0           0
# ..         ...        ...    ...         ...
# 462    -0.5365    -0.4533      0           1
# 356    -0.4734     0.9849      0           0
# 2      -0.1904     0.3840      0           0
# 478     0.7934     0.2027      0           1
# 695     0.1785     0.6924      1           0
#
# [250 rows x 4 columns]

# %%
# Out:
#                      result_type
# prediction label
# 0          0       true_negative
#            1      false_negative
# 1          0      false_positive
#            1       true_positive

# %%
# Out:
#      feature_1  feature_2  label  prediction     result_type
# id
# 993     0.6989    -0.8901      1           1   true_positive
# 859     0.1954    -0.4052      1           1   true_positive
# 298    -1.2008     0.3466      0           0   true_negative
# 553    -0.5357     0.9388      0           0   true_negative
# 672    -1.3599     0.2303      0           0   true_negative
# ..         ...        ...    ...         ...             ...
# 462    -0.5365    -0.4533      0           1  false_positive
# 356    -0.4734     0.9849      0           0   true_negative
# 2      -0.1904     0.3840      0           0   true_negative
# 478     0.7934     0.2027      0           1  false_positive
# 695     0.1785     0.6924      1           0  false_negative
#
# [250 rows x 5 columns]

# %% [markdown]
# # Instructions
#
# - Use `seaborn.scatterplot` to visualize both features and result types of test data
# - Use `sklearn.metrics.confusion_matrix` to calculate the confusion matrix
# - Explain what the numbers in the confusion matrix represent

# %%
# Out:
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='feature_1', ylabel='feature_2'>

# %%
# Out:
# array([[ 96,  21],
#        [ 25, 108]])

# %% [markdown]
# # Instructions
#
# - Use `sklearn.metrics.classification_report` to print the classification report
# - Now, **manually calculate** the following metrics and put them in a Python dictionary
# - The expected output should look like:
#
# ```
# {
#     "true_positive": 108,
#     "true_negative": 96,
#     "false_negative": 25,
#     "false_positive": 21,
#     "accuracy": 0.816,
#     "precision": 0.8372093023255814,
#     "recall": 0.8120300751879699,
#     "support": 133,
#     "f1-score": 0.8244274809160306
# }
# ```
# - Use `json.dump` to save the output to  `./results/scores.test.json`

# %%
# Out:
#                     0           1  accuracy   macro avg  weighted avg
# precision    0.793388    0.837209     0.816    0.815299      0.816701
# recall       0.820513    0.812030     0.816    0.816271      0.816000
# f1-score     0.806723    0.824427     0.816    0.815575      0.816142
# support    117.000000  133.000000     0.816  250.000000    250.000000

# %%
# Out:
# {'true_positive': 108,
#  'true_negative': 96,
#  'false_negative': 25,
#  'false_positive': 21,
#  'accuracy': 0.816,
#  'precision': 0.8372093023255814,
#  'recall': 0.8120300751879699,
#  'support': 133,
#  'f1-score': 0.8244274809160306}
