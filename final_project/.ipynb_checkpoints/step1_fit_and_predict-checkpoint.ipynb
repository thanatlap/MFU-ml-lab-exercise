# %%
import pandas
import seaborn

import sklearn.impute
import sklearn.preprocessing
import sklearn.pipeline
import sklearn.compose
import sklearn.ensemble

# %matplotlib inline

# %%
data_train = pandas.read_csv('./data/high_salary.train.csv').set_index('id')
data_train
# Out:
#        social-security-number  house-number  age-group     workclass  \
# id
# 8616              216208066.0        6278.0        2.0  self-emp-inc
# 21982             404455249.0        1673.0        3.0     local-gov
# 11191             500057524.0        7417.0        0.0       private
# 22229             932067669.0        9740.0        2.0       private
# 20732             417132399.0        6941.0        3.0       private
# ...                       ...           ...        ...           ...
# 21575             448834224.0        3595.0        0.0       private
# 5390              290486928.0        8844.0        3.0       private
# 860               198116565.0        5120.0        3.0       private
# 15795             481902134.0        6430.0        0.0     state-gov
# 23654             687251368.0        9210.0        4.0       private
#
#          fnlwgt     education  education-num      marital-status  \
# id
# 8616   270079.0     bachelors           13.0  married-civ-spouse
# 21982  146325.0     doctorate           16.0  married-civ-spouse
# 11191  240767.0       hs-grad            9.0       never-married
# 22229  118536.0       hs-grad            9.0            divorced
# 20732  160440.0     bachelors           13.0  married-civ-spouse
# ...         ...           ...            ...                 ...
# 21575  147253.0    assoc-acdm           12.0       never-married
# 5390   330543.0     preschool            1.0  married-civ-spouse
# 860     41223.0  some-college           10.0  married-civ-spouse
# 15795  275421.0  some-college           10.0       never-married
# 23654  177271.0       masters           14.0  married-civ-spouse
#
#               occupation    relationship   race     sex  capitalgain  \
# id
# 8616     exec-managerial         husband  white    male          0.0
# 21982     prof-specialty         husband  white    male          0.0
# 11191      other-service   not-in-family  white  female          0.0
# 22229  machine-op-inspct  other-relative  black    male          0.0
# 20732              sales         husband  white    male          0.0
# ...                  ...             ...    ...     ...          ...
# 21575              sales   not-in-family  white    male          0.0
# 5390       other-service         husband  white    male          0.0
# 860         adm-clerical         husband  white    male          0.0
# 15795  machine-op-inspct       own-child  white  female          0.0
# 23654    exec-managerial         husband  white    male          0.0
#
#        capitalloss  hoursperweek native-country-code native-country  label
# id
# 8616           0.0           3.0                 USA  united-states    1.0
# 21982          2.0           2.0                 USA  united-states    1.0
# 11191          0.0           1.0                 USA  united-states    0.0
# 22229          0.0           2.0                 USA  united-states    0.0
# 20732          0.0           3.0                 USA  united-states    1.0
# ...            ...           ...                 ...            ...    ...
# 21575          0.0           2.0                 USA  united-states    0.0
# 5390           0.0           2.0                 MEX         mexico    0.0
# 860            0.0           2.0                 USA  united-states    1.0
# 15795          0.0           2.0                 USA  united-states    0.0
# 23654          0.0           3.0                 USA  united-states    1.0
#
# [20900 rows x 18 columns]

# %%
data_test_features = pandas.read_csv('./data/high_salary.test_features.csv').set_index('id')
data_test_label = pandas.read_csv('./data/high_salary.test_label.csv').set_index('id')

# %%
data_processor = sklearn.compose.ColumnTransformer(transformers=[
    (
        'categorical_data_processor', 
        (
            sklearn.pipeline.Pipeline(steps=[
                ('mode_imputer', sklearn.impute.SimpleImputer(strategy='most_frequent')),
                ('onehot_encoder', sklearn.preprocessing.OneHotEncoder(sparse=False)),
            ])
        ), 
        [
            'age-group',
            'workclass', 
            'marital-status', 
            'occupation', 
            'relationship', 
            'race', 
            'sex', 
            'native-country',
            'native-country-code',

        ]
    ),
    (
        'numerical_data_processor', 
        (
            sklearn.pipeline.Pipeline(steps=[
                ('median_imputer', sklearn.impute.SimpleImputer(strategy='median')),
            ])
        ), 
        [
            'fnlwgt', 
            'education-num', 
            'capitalgain', 
            'capitalloss', 
            'hoursperweek', 
        ]
    ),
])

# %%
model = sklearn.pipeline.Pipeline(steps=[
    ('data_processor', data_processor),
    ('classifier', sklearn.ensemble.RandomForestClassifier(
        n_estimators=100,
        criterion='entropy', 
        max_features=0.5,
        min_samples_split=0.03,
        class_weight='balanced_subsample',
        random_state=0,
    )),
])

# %%
model.fit(
    X = data_train.drop(columns=['label']),
    y = data_train['label']
)
# Out:
# Pipeline(steps=[('data_processor',
#                  ColumnTransformer(transformers=[('categorical_data_processor',
#                                                   Pipeline(steps=[('mode_imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehot_encoder',
#                                                                    OneHotEncoder(sparse=False))]),
#                                                   ['age-group', 'workclass',
#                                                    'marital-status',
#                                                    'occupation', 'relationship',
#                                                    'race', 'sex',
#                                                    'native-country',
#                                                    'native-country-code']),
#                                                  ('numerical_data_processor',
#                                                   Pipeline(steps=[('median_imputer',
#                                                                    SimpleImputer(strategy='median'))]),
#                                                   ['fnlwgt', 'education-num',
#                                                    'capitalgain', 'capitalloss',
#                                                    'hoursperweek'])])),
#                 ('classifier',
#                  RandomForestClassifier(class_weight='balanced_subsample',
#                                         criterion='entropy', max_features=0.5,
#                                         min_samples_split=0.03,
#                                         random_state=0))])

# %%
sklearn.metrics.f1_score(
    y_true = data_train['label'],
    y_pred = model.predict(data_train.drop(columns=['label'])),
)
# Out:
# 0.79593147751606

# %%
sklearn.metrics.f1_score(
    y_true = data_test_label,
    y_pred = model.predict(data_test_features),
)
# Out:
# 0.7970826580226905

# %%
predictions = pandas.DataFrame(
    data = model.predict(data_test_features),
    columns = ['prediction'],
    index = data_test_features.index,
)
predictions
# Out:
#        prediction
# id
# 6111          0.0
# 11214         0.0
# 5554          1.0
# 25131         1.0
# 14324         1.0
# ...           ...
# 25998         1.0
# 8375          0.0
# 13888         0.0
# 4159          1.0
# 9658          0.0
#
# [6967 rows x 1 columns]

# %%
predictions.to_csv('./results/predictions.test.csv')
