# %%
import joblib
import json
import pandas
import warnings

import sklearn.neural_network
import sklearn.model_selection
import sklearn.exceptions

warnings.filterwarnings("ignore", category=sklearn.exceptions.ConvergenceWarning)

# %% [markdown]
# # Instructions
#
# - Read **the train data** from the CSV file and properly set the index

# %%
data_train = pandas.read_csv('./data/features.train.csv').set_index('id')
data_train
# Out:
#      duration  credit_amount       age  checking_status  credit_history  \
# id
# 253  0.277814       0.320904 -0.080669              0.0             0.0
# 667  2.289342       0.130313 -0.765274              0.0             1.0
# 85  -0.727949      -0.642249 -0.594123              0.0             2.0
# 969 -0.811763       0.246356  0.347209              1.0             2.0
# 75  -0.727949      -0.602162  2.572174              1.0             2.0
# ..        ...            ...       ...              ...             ...
# 835 -0.727949      -0.758292  1.031813              1.0             4.0
# 192  0.529255       0.237916  0.004906              2.0             3.0
# 629 -0.979390       0.208730  2.401022              0.0             3.0
# 559 -0.225068      -0.460801 -0.422972              2.0             2.0
# 684  1.283578       2.327386 -0.422972              2.0             0.0
#
#      purpose  savings_status  employment  personal_status  other_parties  ...  \
# id                                                                        ...
# 253      0.0             2.0         2.0              0.0            0.0  ...
# 667      1.0             1.0         2.0              1.0            0.0  ...
# 85       1.0             1.0         2.0              1.0            1.0  ...
# 969      2.0             1.0         2.0              0.0            0.0  ...
# 75       3.0             1.0         4.0              0.0            0.0  ...
# ..       ...             ...         ...              ...            ...  ...
# 835      2.0             1.0         2.0              0.0            0.0  ...
# 192      1.0             1.0         2.0              0.0            0.0  ...
# 629      7.0             0.0         4.0              0.0            0.0  ...
# 559      0.0             1.0         1.0              0.0            0.0  ...
# 684      1.0             2.0         3.0              0.0            0.0  ...
#
#      other_payment_plans  housing  job  own_telephone  foreign_worker  \
# id
# 253                  0.0      2.0  2.0            0.0             1.0
# 667                  1.0      2.0  2.0            0.0             1.0
# 85                   0.0      2.0  3.0            1.0             1.0
# 969                  0.0      2.0  1.0            0.0             1.0
# 75                   0.0      0.0  3.0            0.0             1.0
# ..                   ...      ...  ...            ...             ...
# 835                  2.0      2.0  2.0            0.0             1.0
# 192                  0.0      2.0  2.0            1.0             1.0
# 629                  0.0      2.0  1.0            0.0             1.0
# 559                  0.0      2.0  1.0            0.0             1.0
# 684                  0.0      2.0  1.0            1.0             1.0
#
#      installment_commitment  residence_since  existing_credits  \
# id
# 253                     1.0              2.0               1.0
# 667                     0.0              0.0               0.0
# 85                      3.0              1.0               1.0
# 969                     0.0              1.0               1.0
# 75                      3.0              3.0               1.0
# ..                      ...              ...               ...
# 835                     3.0              3.0               1.0
# 192                     3.0              1.0               0.0
# 629                     0.0              3.0               0.0
# 559                     1.0              1.0               1.0
# 684                     0.0              2.0               1.0
#
#      num_dependents  label
# id
# 253             0.0    0.0
# 667             0.0    0.0
# 85              0.0    0.0
# 969             1.0    0.0
# 75              0.0    0.0
# ..              ...    ...
# 835             0.0    1.0
# 192             1.0    1.0
# 629             0.0    0.0
# 559             0.0    1.0
# 684             1.0    0.0
#
# [750 rows x 21 columns]

# %%
search_parameters = {
    'hidden_layer_sizes': [(10, 5), (10, 5, 2), (5, 2)],
    'activation': ('tanh','logistic'),
    'learning_rate_init': [0.01, 0.1, 0.5]
}

# %%
model = sklearn.neural_network.MLPClassifier(
    hidden_layer_sizes=(10,50),
    solver='sgd', 
    activation='tanh',
    alpha=0.0,  
    batch_size=32,
    learning_rate='constant',
    learning_rate_init=0.5,
    max_iter=1000,
    momentum=0.0, 
    nesterovs_momentum=False, 
    shuffle=True,
    random_state=0
)

# %%
model = sklearn.model_selection.GridSearchCV(
    estimator=model, 
    param_grid=search_parameters,
    n_jobs=-1,
    verbose=2
)

# %%
model.fit(
    data_train.drop(['label'], axis='columns'),
    data_train['label'],
)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# GridSearchCV(estimator=MLPClassifier(activation='tanh', alpha=0.0,
#                                      batch_size=32, hidden_layer_sizes=(10, 50),
#                                      learning_rate_init=0.5, max_iter=1000,
#                                      momentum=0.0, nesterovs_momentum=False,
#                                      random_state=0, solver='sgd'),
#              n_jobs=-1,
#              param_grid={'activation': ('tanh', 'logistic'),
#                          'hidden_layer_sizes': [(10, 5), (10, 5, 2), (5, 2)],
#                          'learning_rate_init': [0.01, 0.1, 0.5]},
#              verbose=2)

# %%
cv_results = pandas.DataFrame(model.cv_results_)
cv_results
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        5.171825      0.522446         0.002552        0.000663
# 1        1.257809      0.291841         0.002859        0.001096
# 2        0.735147      0.229950         0.004831        0.005105
# 3        4.166158      0.412173         0.001941        0.000321
# 4        0.898196      0.255973         0.002198        0.000557
# 5        0.603243      0.148159         0.002423        0.000531
# 6        2.552202      1.220218         0.002225        0.000698
# 7        1.040998      0.291687         0.002020        0.000333
# 8        0.455076      0.089470         0.001826        0.000181
# 9        0.187144      0.006726         0.001832        0.000280
# 10       1.569460      0.860616         0.001749        0.000161
# 11       1.097583      0.197406         0.001934        0.000468
# 12       0.322943      0.033445         0.002038        0.000136
# 13       0.111325      0.009730         0.001814        0.000271
# 14       0.094589      0.020391         0.002010        0.000449
# 15       0.315169      0.030785         0.001771        0.000180
# 16       0.532148      0.870233         0.002201        0.000867
# 17       1.019888      0.193425         0.002103        0.000779
#
#    param_activation param_hidden_layer_sizes param_learning_rate_init  \
# 0              tanh                  (10, 5)                     0.01
# 1              tanh                  (10, 5)                      0.1
# 2              tanh                  (10, 5)                      0.5
# 3              tanh               (10, 5, 2)                     0.01
# 4              tanh               (10, 5, 2)                      0.1
# 5              tanh               (10, 5, 2)                      0.5
# 6              tanh                   (5, 2)                     0.01
# 7              tanh                   (5, 2)                      0.1
# 8              tanh                   (5, 2)                      0.5
# 9          logistic                  (10, 5)                     0.01
# 10         logistic                  (10, 5)                      0.1
# 11         logistic                  (10, 5)                      0.5
# 12         logistic               (10, 5, 2)                     0.01
# 13         logistic               (10, 5, 2)                      0.1
# 14         logistic               (10, 5, 2)                      0.5
# 15         logistic                   (5, 2)                     0.01
# 16         logistic                   (5, 2)                      0.1
# 17         logistic                   (5, 2)                      0.5
#
#                                                params  split0_test_score  \
# 0   {'activation': 'tanh', 'hidden_layer_sizes': (...           0.686667
# 1   {'activation': 'tanh', 'hidden_layer_sizes': (...           0.700000
# 2   {'activation': 'tanh', 'hidden_layer_sizes': (...           0.733333
# 3   {'activation': 'tanh', 'hidden_layer_sizes': (...           0.726667
# 4   {'activation': 'tanh', 'hidden_layer_sizes': (...           0.720000
# 5   {'activation': 'tanh', 'hidden_layer_sizes': (...           0.726667
# 6   {'activation': 'tanh', 'hidden_layer_sizes': (...           0.713333
# 7   {'activation': 'tanh', 'hidden_layer_sizes': (...           0.686667
# 8   {'activation': 'tanh', 'hidden_layer_sizes': (...           0.653333
# 9   {'activation': 'logistic', 'hidden_layer_sizes...           0.700000
# 10  {'activation': 'logistic', 'hidden_layer_sizes...           0.713333
# 11  {'activation': 'logistic', 'hidden_layer_sizes...           0.706667
# 12  {'activation': 'logistic', 'hidden_layer_sizes...           0.700000
# 13  {'activation': 'logistic', 'hidden_layer_sizes...           0.700000
# 14  {'activation': 'logistic', 'hidden_layer_sizes...           0.700000
# 15  {'activation': 'logistic', 'hidden_layer_sizes...           0.700000
# 16  {'activation': 'logistic', 'hidden_layer_sizes...           0.700000
# 17  {'activation': 'logistic', 'hidden_layer_sizes...           0.713333
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.673333           0.746667           0.680000
# 1            0.653333           0.733333           0.706667
# 2            0.633333           0.633333           0.666667
# 3            0.653333           0.706667           0.660000
# 4            0.693333           0.673333           0.713333
# 5            0.686667           0.713333           0.680000
# 6            0.666667           0.686667           0.700000
# 7            0.660000           0.653333           0.726667
# 8            0.660000           0.693333           0.653333
# 9            0.700000           0.700000           0.700000
# 10           0.693333           0.686667           0.680000
# 11           0.680000           0.666667           0.746667
# 12           0.700000           0.700000           0.700000
# 13           0.700000           0.700000           0.700000
# 14           0.700000           0.700000           0.700000
# 15           0.700000           0.700000           0.700000
# 16           0.686667           0.700000           0.700000
# 17           0.666667           0.720000           0.700000
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.720000         0.701333        0.027777                2
# 1            0.660000         0.690667        0.029993               13
# 2            0.613333         0.656000        0.042290               18
# 3            0.666667         0.682667        0.028783               14
# 4            0.546667         0.669333        0.063470               16
# 5            0.713333         0.704000        0.017689                1
# 6            0.720000         0.697333        0.019137                9
# 7            0.680000         0.681333        0.025785               15
# 8            0.680000         0.668000        0.016000               17
# 9            0.693333         0.698667        0.002667                4
# 10           0.700000         0.694667        0.011470               12
# 11           0.680000         0.696000        0.028472               11
# 12           0.693333         0.698667        0.002667                4
# 13           0.693333         0.698667        0.002667                4
# 14           0.693333         0.698667        0.002667                4
# 15           0.693333         0.698667        0.002667                4
# 16           0.693333         0.696000        0.005333               10
# 17           0.700000         0.700000        0.018379                3

# %%
cv_results.sort_values(['rank_test_score'])
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 5        0.603243      0.148159         0.002423        0.000531
# 0        5.171825      0.522446         0.002552        0.000663
# 17       1.019888      0.193425         0.002103        0.000779
# 9        0.187144      0.006726         0.001832        0.000280
# 12       0.322943      0.033445         0.002038        0.000136
# 13       0.111325      0.009730         0.001814        0.000271
# 14       0.094589      0.020391         0.002010        0.000449
# 15       0.315169      0.030785         0.001771        0.000180
# 6        2.552202      1.220218         0.002225        0.000698
# 16       0.532148      0.870233         0.002201        0.000867
# 11       1.097583      0.197406         0.001934        0.000468
# 10       1.569460      0.860616         0.001749        0.000161
# 1        1.257809      0.291841         0.002859        0.001096
# 3        4.166158      0.412173         0.001941        0.000321
# 7        1.040998      0.291687         0.002020        0.000333
# 4        0.898196      0.255973         0.002198        0.000557
# 8        0.455076      0.089470         0.001826        0.000181
# 2        0.735147      0.229950         0.004831        0.005105
#
#    param_activation param_hidden_layer_sizes param_learning_rate_init  \
# 5              tanh               (10, 5, 2)                      0.5
# 0              tanh                  (10, 5)                     0.01
# 17         logistic                   (5, 2)                      0.5
# 9          logistic                  (10, 5)                     0.01
# 12         logistic               (10, 5, 2)                     0.01
# 13         logistic               (10, 5, 2)                      0.1
# 14         logistic               (10, 5, 2)                      0.5
# 15         logistic                   (5, 2)                     0.01
# 6              tanh                   (5, 2)                     0.01
# 16         logistic                   (5, 2)                      0.1
# 11         logistic                  (10, 5)                      0.5
# 10         logistic                  (10, 5)                      0.1
# 1              tanh                  (10, 5)                      0.1
# 3              tanh               (10, 5, 2)                     0.01
# 7              tanh                   (5, 2)                      0.1
# 4              tanh               (10, 5, 2)                      0.1
# 8              tanh                   (5, 2)                      0.5
# 2              tanh                  (10, 5)                      0.5
#
#                                                params  split0_test_score  \
# 5   {'activation': 'tanh', 'hidden_layer_sizes': (...           0.726667
# 0   {'activation': 'tanh', 'hidden_layer_sizes': (...           0.686667
# 17  {'activation': 'logistic', 'hidden_layer_sizes...           0.713333
# 9   {'activation': 'logistic', 'hidden_layer_sizes...           0.700000
# 12  {'activation': 'logistic', 'hidden_layer_sizes...           0.700000
# 13  {'activation': 'logistic', 'hidden_layer_sizes...           0.700000
# 14  {'activation': 'logistic', 'hidden_layer_sizes...           0.700000
# 15  {'activation': 'logistic', 'hidden_layer_sizes...           0.700000
# 6   {'activation': 'tanh', 'hidden_layer_sizes': (...           0.713333
# 16  {'activation': 'logistic', 'hidden_layer_sizes...           0.700000
# 11  {'activation': 'logistic', 'hidden_layer_sizes...           0.706667
# 10  {'activation': 'logistic', 'hidden_layer_sizes...           0.713333
# 1   {'activation': 'tanh', 'hidden_layer_sizes': (...           0.700000
# 3   {'activation': 'tanh', 'hidden_layer_sizes': (...           0.726667
# 7   {'activation': 'tanh', 'hidden_layer_sizes': (...           0.686667
# 4   {'activation': 'tanh', 'hidden_layer_sizes': (...           0.720000
# 8   {'activation': 'tanh', 'hidden_layer_sizes': (...           0.653333
# 2   {'activation': 'tanh', 'hidden_layer_sizes': (...           0.733333
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 5            0.686667           0.713333           0.680000
# 0            0.673333           0.746667           0.680000
# 17           0.666667           0.720000           0.700000
# 9            0.700000           0.700000           0.700000
# 12           0.700000           0.700000           0.700000
# 13           0.700000           0.700000           0.700000
# 14           0.700000           0.700000           0.700000
# 15           0.700000           0.700000           0.700000
# 6            0.666667           0.686667           0.700000
# 16           0.686667           0.700000           0.700000
# 11           0.680000           0.666667           0.746667
# 10           0.693333           0.686667           0.680000
# 1            0.653333           0.733333           0.706667
# 3            0.653333           0.706667           0.660000
# 7            0.660000           0.653333           0.726667
# 4            0.693333           0.673333           0.713333
# 8            0.660000           0.693333           0.653333
# 2            0.633333           0.633333           0.666667
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 5            0.713333         0.704000        0.017689                1
# 0            0.720000         0.701333        0.027777                2
# 17           0.700000         0.700000        0.018379                3
# 9            0.693333         0.698667        0.002667                4
# 12           0.693333         0.698667        0.002667                4
# 13           0.693333         0.698667        0.002667                4
# 14           0.693333         0.698667        0.002667                4
# 15           0.693333         0.698667        0.002667                4
# 6            0.720000         0.697333        0.019137                9
# 16           0.693333         0.696000        0.005333               10
# 11           0.680000         0.696000        0.028472               11
# 10           0.700000         0.694667        0.011470               12
# 1            0.660000         0.690667        0.029993               13
# 3            0.666667         0.682667        0.028783               14
# 7            0.680000         0.681333        0.025785               15
# 4            0.546667         0.669333        0.063470               16
# 8            0.680000         0.668000        0.016000               17
# 2            0.613333         0.656000        0.042290               18

# %%
model.best_params_
# Out:
# {'activation': 'tanh',
#  'hidden_layer_sizes': (10, 5, 2),
#  'learning_rate_init': 0.5}
