# %%
import joblib
import json
import pandas

import sklearn.neighbors

# %% [markdown]
# # Instructions
#
# - Read **the train data** from the CSV file and properly set the index

# %%
# Out:
#      duration  credit_amount       age  employment  credit_history_all paid  \
# id
# 253  0.284625       0.315530 -0.079689         2.0                      0.0
# 667  2.308525       0.126008 -0.763872         2.0                      1.0
# 85  -0.727325      -0.642219 -0.592826         2.0                      0.0
# 969 -0.811654       0.241399  0.347925         2.0                      0.0
# 75  -0.727325      -0.602357  2.571519         4.0                      0.0
# ..        ...            ...       ...         ...                      ...
# 835 -0.727325      -0.757610  1.032108         2.0                      0.0
# 192  0.537613       0.233007  0.005834         2.0                      0.0
# 629 -0.980312       0.203985  2.400474         4.0                      0.0
# 559 -0.221350      -0.461789 -0.421781         1.0                      0.0
# 684  1.296575       2.310752 -0.421781         3.0                      0.0
#
#      credit_history_critical/other existing credit  \
# id
# 253                                            0.0
# 667                                            0.0
# 85                                             1.0
# 969                                            1.0
# 75                                             1.0
# ..                                             ...
# 835                                            0.0
# 192                                            0.0
# 629                                            0.0
# 559                                            1.0
# 684                                            0.0
#
#      credit_history_existing paid  credit_history_no credits/all paid  \
# id
# 253                           0.0                                 0.0
# 667                           0.0                                 0.0
# 85                            0.0                                 0.0
# 969                           0.0                                 0.0
# 75                            0.0                                 0.0
# ..                            ...                                 ...
# 835                           0.0                                 1.0
# 192                           1.0                                 0.0
# 629                           1.0                                 0.0
# 559                           0.0                                 0.0
# 684                           0.0                                 0.0
#
#      savings_status_no known savings  savings_status_<100  \
# id
# 253                              0.0                  0.0
# 667                              0.0                  1.0
# 85                               0.0                  1.0
# 969                              0.0                  1.0
# 75                               0.0                  1.0
# ..                               ...                  ...
# 835                              0.0                  1.0
# 192                              0.0                  1.0
# 629                              1.0                  0.0
# 559                              0.0                  1.0
# 684                              0.0                  0.0
#
#      savings_status_100<=X<500  savings_status_500<=X<1000  \
# id
# 253                        1.0                         0.0
# 667                        0.0                         0.0
# 85                         0.0                         0.0
# 969                        0.0                         0.0
# 75                         0.0                         0.0
# ..                         ...                         ...
# 835                        0.0                         0.0
# 192                        0.0                         0.0
# 629                        0.0                         0.0
# 559                        0.0                         0.0
# 684                        1.0                         0.0
#
#      savings_status_>=1000  label
# id
# 253                    0.0    0.0
# 667                    0.0    0.0
# 85                     0.0    0.0
# 969                    0.0    0.0
# 75                     0.0    0.0
# ..                     ...    ...
# 835                    0.0    1.0
# 192                    0.0    1.0
# 629                    0.0    0.0
# 559                    0.0    1.0
# 684                    0.0    0.0
#
# [733 rows x 14 columns]

# %% [markdown]
# # Instructions
#
# - Instantiate a `sklearn.neighbors.KNeighborsClassifier` model with the following configurations
# ```
#     n_neighbors=5,
#     weights='uniform',
#     p=2,
# ```
# - Fit the model with data columns properly selected
# - Use `joblib.dump` to save the model to `./model/model.joblib`
# - Also, use `.get_params`, `json.dump` to save the model configuration to  `./model/config.json`

# %%
# Out:
# KNeighborsClassifier()

# %%
# Out:
# ['./model/model.joblib']
