# %%
import numpy
import pandas
import joblib
import json
import seaborn

import sklearn

# %matplotlib inline

# %% [markdown]
# # Instructions
#
# - Read **the test data** from the CSV file and properly set the index
# - Load the trained model

# %%
# Out:
#      feature_1   label
# id
# 993     0.0412 -0.0089
# 859    -0.8460  0.7467
# 298     2.8375  2.4456
# 553     0.1197 -0.7088
# 672     0.6872  0.1937
# ..         ...     ...
# 462    -0.7542  0.9809
# 356    -1.3344  0.6540
# 2       0.6166 -0.4633
# 478     2.9664  3.4442
# 695    -0.8094 -0.4599
#
# [250 rows x 2 columns]

# %%
# Out:
# Pipeline(steps=[('polynomial_features',
#                  PolynomialFeatures(degree=15, include_bias=False)),
#                 ('linear_regression', Ridge(alpha=10000.0))])

# %% [markdown]
# # Instructions
#
# - Calculate and add the `prediction` column to the dataframe of test data
# - Calculate and add the `residual` column to the dataframe
#   - Hint: $\epsilon = y_{\mathrm{label}} - y_{\mathrm{prediction}}$
# - Write the dataframe to `./result/predictions.test.csv`

# %%
# Out:
#      feature_1   label  prediction
# id
# 993     0.0412 -0.0089    0.049135
# 859    -0.8460  0.7467    0.029114
# 298     2.8375  2.4456    2.654314
# 553     0.1197 -0.7088    0.049684
# 672     0.6872  0.1937    0.059157
# ..         ...     ...         ...
# 462    -0.7542  0.9809    0.035245
# 356    -1.3344  0.6540   -0.091772
# 2       0.6166 -0.4633    0.056653
# 478     2.9664  3.4442    2.972616
# 695    -0.8094 -0.4599    0.031852
#
# [250 rows x 3 columns]

# %%
# Out:
#      feature_1   label  prediction  residual
# id
# 993     0.0412 -0.0089    0.049135 -0.058035
# 859    -0.8460  0.7467    0.029114  0.717586
# 298     2.8375  2.4456    2.654314 -0.208714
# 553     0.1197 -0.7088    0.049684 -0.758484
# 672     0.6872  0.1937    0.059157  0.134543
# ..         ...     ...         ...       ...
# 462    -0.7542  0.9809    0.035245  0.945655
# 356    -1.3344  0.6540   -0.091772  0.745772
# 2       0.6166 -0.4633    0.056653 -0.519953
# 478     2.9664  3.4442    2.972616  0.471584
# 695    -0.8094 -0.4599    0.031852 -0.491752
#
# [250 rows x 4 columns]

# %% [markdown]
# # Instructions
#
# - Use `seaborn.scatterplot` to visualize the predictions against the residuals
# - Discuss what the visualization might suggest

# %%
# Out:
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /opt/conda/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# # Instructions
#
# - Use the following functions to evaluate the predictions and put them in a Python dictionary
# ```
#     sklearn.metrics.mean_squared_error,
#     sklearn.metrics.mean_absolute_error,
#     sklearn.metrics.mean_absolute_percentage_error,
#     sklearn.metrics.r2_score,
# ```
#
# - The expected output should look like:
# ```
# {
#      'mean_squared_error': 0.9521102714472106,
#      'mean_absolute_error': 0.7774567495522493,
#      'mean_absolute_percentage_error': 1.23745298766299,
#      'r2_score': 0.5239019542236285
# }
# ```
# - Use `json.dump` to save the output to  `./results/scores.test.json`
# - Explain what each metric represents

# %%
# Out:
# {'mean_squared_error': 0.9521102714401528,
#  'mean_absolute_error': 0.7774567495502672,
#  'mean_absolute_percentage_error': 1.2374529876649714,
#  'r2_score': 0.5239019542271577}
